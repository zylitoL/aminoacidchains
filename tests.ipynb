# %%
import txt2graph
import brute
import fakeid3
import approx
mats = txt2graph.mats("compact.txt")

# %%
# %timeit brute.bruteforce(mats)
# Out:
# 2.13 s ± 31.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit approx.minhitset(mats)
# Out:
# 108 ms ± 11 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit fakeid3.id3wrapper(mats)
# Out:
# 48.3 ms ± 5.94 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
